# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('LIDC-IDRI_MetaData.csv')
df1_sorted = df1.sort_values(by='Subject ID')
df1_sorted
# Out:
#           Subject ID                                          Study UID  \
# 348   LIDC-IDRI-0001  1.3.6.1.4.1.14519.5.2.1.6279.6001.298806137288...
# 186   LIDC-IDRI-0001  1.3.6.1.4.1.14519.5.2.1.6279.6001.175012972118...
# 1100  LIDC-IDRI-0002  1.3.6.1.4.1.14519.5.2.1.6279.6001.116951808801...
# 1141  LIDC-IDRI-0002  1.3.6.1.4.1.14519.5.2.1.6279.6001.490157381160...
# 189   LIDC-IDRI-0003  1.3.6.1.4.1.14519.5.2.1.6279.6001.202063331127...
# ...              ...                                                ...
# 990   LIDC-IDRI-1008  1.3.6.1.4.1.14519.5.2.1.6279.6001.339975625902...
# 1248  LIDC-IDRI-1009  1.3.6.1.4.1.14519.5.2.1.6279.6001.849069697860...
# 1120  LIDC-IDRI-1010  1.3.6.1.4.1.14519.5.2.1.6279.6001.145373944605...
# 749   LIDC-IDRI-1011  1.3.6.1.4.1.14519.5.2.1.6279.6001.287560874054...
# 242   LIDC-IDRI-1012  1.3.6.1.4.1.14519.5.2.1.6279.6001.676549258486...
#
#            Study Description             Study Date  \
# 348                      NaN  2000-01-01 00:00:00.0
# 186                      NaN  2000-01-01 00:00:00.0
# 1100                     NaN  2000-01-01 00:00:00.0
# 1141                     NaN  2000-01-01 00:00:00.0
# 189                      NaN  2000-01-01 00:00:00.0
# ...                      ...                    ...
# 990                      NaN  2000-01-01 00:00:00.0
# 1248    CT THORAX W/CONTRAST  2000-01-01 00:00:00.0
# 1120  CT ANGIO CHEST (NON-CO  2000-01-01 00:00:00.0
# 749     CT THORAX W/CONTRAST  2000-01-01 00:00:00.0
# 242                    CHEST  2000-01-01 00:00:00.0
#
#                                               Series ID Series Description  \
# 348   1.3.6.1.4.1.14519.5.2.1.6279.6001.179049373636...                NaN
# 186   1.3.6.1.4.1.14519.5.2.1.6279.6001.141365756818...                NaN
# 1100  1.3.6.1.4.1.14519.5.2.1.6279.6001.493562949900...                NaN
# 1141  1.3.6.1.4.1.14519.5.2.1.6279.6001.619372068417...                NaN
# 189   1.3.6.1.4.1.14519.5.2.1.6279.6001.142026812390...                NaN
# ...                                                 ...                ...
# 990   1.3.6.1.4.1.14519.5.2.1.6279.6001.332510758903...                NaN
# 1248  1.3.6.1.4.1.14519.5.2.1.6279.6001.855232435861...     Recon 2: CHEST
# 1120  1.3.6.1.4.1.14519.5.2.1.6279.6001.550599855064...      BOTTOM TO TOP
# 749   1.3.6.1.4.1.14519.5.2.1.6279.6001.272123398257...              CHEST
# 242   1.3.6.1.4.1.14519.5.2.1.6279.6001.153646219551...                NaN
#
#       Number of images  File Size (Bytes) Collection Name Modality  \
# 348                133           70018838       LIDC-IDRI       CT
# 186                  2           16357620       LIDC-IDRI       DX
# 1100                 1            6909958       LIDC-IDRI       DX
# 1141               261          137396696       LIDC-IDRI       CT
# 189                  5           38580794       LIDC-IDRI       DX
# ...                ...                ...             ...      ...
# 990                115           60517648       LIDC-IDRI       CT
# 1248               125           65830674       LIDC-IDRI       CT
# 1120               252          132720966       LIDC-IDRI       CT
# 749                133           70030058       LIDC-IDRI       CT
# 242                166           87399298       LIDC-IDRI       CT
#
#             Manufacturer
# 348   GE MEDICAL SYSTEMS
# 186   GE MEDICAL SYSTEMS
# 1100  GE MEDICAL SYSTEMS
# 1141  GE MEDICAL SYSTEMS
# 189   GE MEDICAL SYSTEMS
# ...                  ...
# 990              TOSHIBA
# 1248  GE MEDICAL SYSTEMS
# 1120  GE MEDICAL SYSTEMS
# 749   GE MEDICAL SYSTEMS
# 242   GE MEDICAL SYSTEMS
#
# [1308 rows x 11 columns]

# %%
df2 = pd.read_excel('lidc-idri nodule counts (6-23-2015).xlsx')
df2_sorted = df2.sort_values(by='TCIA Patent ID')
df2_sorted
# Out:
#       TCIA Patent ID  Total Number of Nodules*   Number of Nodules >=3mm**  \
# 0     LIDC-IDRI-0001                          4                          1
# 1     LIDC-IDRI-0002                         12                          1
# 2     LIDC-IDRI-0003                          4                          4
# 3     LIDC-IDRI-0004                          4                          1
# 4     LIDC-IDRI-0005                          9                          3
# ...              ...                        ...                        ...
# 1014  LIDC-IDRI-1009                          2                          1
# 1015  LIDC-IDRI-1010                         10                          1
# 1016  LIDC-IDRI-1011                          4                          4
# 1017  LIDC-IDRI-1012                          1                          1
# 1018             NaN                       7371                       2669
#
#       Number of Nodules <3mm***  Unnamed: 4  \
# 0                             3         NaN
# 1                            11         NaN
# 2                             0         NaN
# 3                             3         NaN
# 4                             6         NaN
# ...                         ...         ...
# 1014                          1         NaN
# 1015                          9         NaN
# 1016                          0         NaN
# 1017                          0         NaN
# 1018                       4702         NaN
#
#                                              Unnamed: 5
# 0                                                   NaN
# 1     *total number of lesions that received either ...
# 2     **total number of lesions that received a "nod...
# 3     ***total number of lesions that received a "no...
# 4                                                   NaN
# ...                                                 ...
# 1014                                                NaN
# 1015                                                NaN
# 1016                                                NaN
# 1017                                                NaN
# 1018                                                NaN
#
# [1019 rows x 6 columns]

# %%
df3 = pd.read_excel('tcia-diagnosis-data-2012-04-20.xls')
df3_sorted = df3.sort_values(by='TCIA Patient ID')
df3_sorted
# Out:
#     TCIA Patient ID  \
# 0    LIDC-IDRI-0068
# 1    LIDC-IDRI-0071
# 2    LIDC-IDRI-0072
# 3    LIDC-IDRI-0088
# 4    LIDC-IDRI-0090
# ..              ...
# 152  LIDC-IDRI-0994
# 153  LIDC-IDRI-1002
# 154  LIDC-IDRI-1004
# 155  LIDC-IDRI-1010
# 156  LIDC-IDRI-1011
#
#      Diagnosis at the Patient Level\n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic\n  \
# 0                                                    3
# 1                                                    3
# 2                                                    2
# 3                                                    3
# 4                                                    2
# ..                                                 ...
# 152                                                  2
# 153                                                  2
# 154                                                  2
# 155                                                  0
# 156                                                  3
#
#      Diagnosis Method\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response  \
# 0                                                    4
# 1                                                    1
# 2                                                    4
# 3                                                    0
# 4                                                    3
# ..                                                 ...
# 152                                                  3
# 153                                                  2
# 154                                                  3
# 155                                                  0
# 156                                                  2
#
#     Primary tumor site for metastatic disease  \
# 0                          Head & Neck Cancer
# 1                                Head & Neck
# 2                                 Lung Cancer
# 3                              Uterine Cancer
# 4                                       NSCLC
# ..                                        ...
# 152                         LUL Large cell CA
# 153                  non-small cell carcinoma
# 154                                 LUL NSCLC
# 155                                  lymphoma
# 156        small-cell carcinoma of the tongue
#
#      Nodule 1\nDiagnosis at the Nodule Level \n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic)\n  \
# 0                                                  3.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  0.0
# 4                                                  2.0
# ..                                                 ...
# 152                                                2.0
# 153                                                NaN
# 154                                                2.0
# 155                                                0.0
# 156                                                3.0
#
#      Nodule 1\nDiagnosis Method at the Nodule Level\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response\n  \
# 0                                                  4.0
# 1                                                  1.0
# 2                                                  4.0
# 3                                                  0.0
# 4                                                  3.0
# ..                                                 ...
# 152                                                3.0
# 153                                                NaN
# 154                                                3.0
# 155                                                0.0
# 156                                                2.0
#
#      Nodule 2\nDiagnosis at the Nodule Level \n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic)\n  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                3.0
#
#      Nodule 2\nDiagnosis Method at the Nodule Level\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response\n  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                4.0
#
#     Nodule 3\nDiagnosis at the Nodule Level \n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic)\n  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                NaN
#
#     Nodule 3\nDiagnosis Method at the Nodule Level\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response\n  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                NaN
#
#      Nodule 4\nDiagnosis at the Nodule Level \n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic)\n  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                NaN
#
#      Nodule 4\nDiagnosis Method at the Nodule Level\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response\n  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                NaN
#
#      Nodule 5\nDiagnosis at the Nodule Level \n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic)\n  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                NaN
#
#      Nodule 5\nDiagnosis Method at the Nodule Level\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response\n
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                NaN
#
# [157 rows x 14 columns]

# %%
import pylidc as pyl

# Query for all CT scans with desired traits.
scans = pyl.query(pyl.Scan).filter(pyl.Scan.slice_thickness <= 1,
                                 pyl.Scan.pixel_spacing <= 0.6)
print(scans.count())
# => 31

pid = 'LIDC-IDRI-0006'
scan = pyl.query(pyl.Scan).filter(pyl.Scan.patient_id == pid).first()

# ann=pyl.query(pyl.Annotation).first()
# print(ann.scan.patient_id)
# Out:
# 31

# %%
print(len(scan.annotations))
# => 8 anotaçoes de nodulos, serao as 8 anotaçoes do mesmo nodulo?
# Out:
# 8

# %%
#verificar os nodulos e a quantidade de anotocoes de cada um
nods=scan.cluster_annotations()
print("%s has %d nodules." % (scan, len(nods)))
# => Scan(id=17,patient_id=LIDC-IDRI-0006) has 4 nodules.
# Out:
# Scan(id=17,patient_id=LIDC-IDRI-0006) has 4 nodules.

# %%
for i,nod in enumerate(nods):
    print("Nodule %d has %d annotations" % (i+1, len(nods[i])))
# => Nodule 1 has 1 annotations
# => Nodule 2 has 2 annotations
# => Nodule 3 has 1 annotations
# => Nodule 4 has 4 annotations
# Out:
# Nodule 1 has 1 annotations
# Nodule 2 has 2 annotations
# Nodule 3 has 1 annotations
# Nodule 4 has 4 annotations

# %%
id=df2['TCIA Patent ID'] == 'LIDC-IDRI-0006'
numero_de_nodulos = df2.loc[id, 'Total Number of Nodules* ']
print(numero_de_nodulos)
#nao bate certo com o numero de nos
# Out:
# 5    14
# Name: Total Number of Nodules* , dtype: int64

# %%
#converting scan image values to numpay
# vol=scan.to_volume()
# print(vol.shape)
#nao funciona devido ao path para as imagens, nao sei ate 
#que ponto é sequer essencial

# %%
import os
import pydicom
import numpy as np
import matplotlib.pyplot as plt

# Caminho para a pasta que contém as pastas LIDC-IDRI-XXXX
diretorio_principal = "C:\\Users\\beatr\\Desktop\\UNI\\3ºANO\\Lab IA CD\\Trabalho\\imagens"

# Lista para armazenar os volumes de cada escaneamento
volumes = []

# Iterar pelas pastas LIDC-IDRI-XXXX
for pasta in os.listdir(diretorio_principal):
    pasta_completa = os.path.join(diretorio_principal, pasta)
    
    if os.path.isdir(pasta_completa):
        # Encontrar todos os arquivos DICOM nas subpastas
        arquivos_dicom = []
        for root, _, files in os.walk(pasta_completa):
            for file in files:
                if file.endswith(".dcm"):
                    arquivos_dicom.append(os.path.join(root, file))

        # Carregar os arquivos DICOM e criar um volume
        volume = []
        shape = None
        for arquivo_dicom in arquivos_dicom:
            dcm = pydicom.dcmread(arquivo_dicom)
            if shape is None:
                shape = dcm.pixel_array.shape
            if shape == dcm.pixel_array.shape:
                volume.append(dcm.pixel_array)
        
        if volume:
            volume = np.stack(volume, axis=-1).astype(np.int16)
            volumes.append(volume)

# Agora você tem uma lista 'volumes' com os volumes de cada escaneamento
# volumes[0] contém o volume do primeiro escaneamento, volumes[1] contém o volume do segundo, e assim por diante

# Visualizar o primeiro volume (ou o volume desejado)
plt.imshow(volumes[0][:, :, 0], cmap='gray')
plt.show()

# %%
scan.visualize(annotation_groups=nods)
# Out:
# Loading dicom files ... This may take a moment.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 scan.visualize(annotation_groups=nods)
#
# File ~\anaconda3\lib\site-packages\pylidc\Scan.py:498, in Scan.visualize(self, annotation_groups)
#     476 def visualize(self, annotation_groups=None):
#     477     """
#     478     Visualize the scan.
#     479
#    (...)
#     496
#     497     """
# --> 498     images = self.load_all_dicom_images()
#     500     fig = plt.figure(figsize=(16,8))
#     501     current_slice = int( len(images) / 2 )
#
# File ~\anaconda3\lib\site-packages\pylidc\Scan.py:288, in Scan.load_all_dicom_images(self, verbose)
#     261 """
#     262 Load all the DICOM images assocated with this scan and return as list.
#     263
#    (...)
#     284
#     285 """
#     286 if verbose: print("Loading dicom files ... This may take a moment.")
# --> 288 path = self.get_path_to_dicom_files()
#     289 fnames = [fname for fname in os.listdir(path)
#     290                     if fname.endswith('.dcm') and not fname.startswith(".")]
#     291 images = []
#
# File ~\anaconda3\lib\site-packages\pylidc\Scan.py:215, in Scan.get_path_to_dicom_files(self)
#     211 if not os.path.exists(dicompath):
#     212     msg = ("Could not establish path to dicom files. Have you "
#     213            "specified the `path` option in the configuration "
#     214            "file {}?")
# --> 215     raise RuntimeError(msg.format(_get_config_file()))
#     217 base = os.path.join(dicompath, self.patient_id)
#     219 if not os.path.exists(base):
#
# RuntimeError: Could not establish path to dicom files. Have you specified the `path` option in the configuration file C:\Users\beatr\pylidc.conf?
